# %%
#Reinforcement learning
#Autonomous driving
#Securities Trading
#Neural Network Architecture Search
#Simulated Training of Robots

# %%
import os
import gym
from stable_baselines3 import PPO
from stable_baselines3.common.vec_env import DummyVecEnv
from stable_baselines3.common.evaluation import evaluate_policy

#https://gym.openai.com/docs


environment_name= "CartPole-v0"
env = gym.make(environment_name)

episodes = 0
for episode in range(1,episodes+1):
    state = env.reset();
    done=False;
    score =0;
    i=0;
    while i<1000:
        i+=1
        env.render();
        action = env.action_space.sample();
        n_state, reward, done, info =env.step(action)
        score+=reward;
        
env.close()

# %%
env.close();

# %%
log_path = os.path.join('training','logs')

env=gym.make(environment_name)
env=DummyVecEnv([lambda:env])
model=PPO('MlpPolicy', env, verbose =1 , tensorboard_log=log_path)

model.learn(total_timesteps=20000)

PPO_path = os.path.join('training','saved-models')
model.save(PPO_path)
# Out:
# Using cpu device
# Logging to training/logs/PPO_4
# -----------------------------
# | time/              |      |
# |    fps             | 2609 |
# |    iterations      | 1    |
# |    time_elapsed    | 0    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1746        |
# |    iterations           | 2           |
# |    time_elapsed         | 2           |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.008595583 |
# |    clip_fraction        | 0.11        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.686      |
# |    explained_variance   | 0.00151     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 6.63        |
# |    n_updates            | 10          |
# |    policy_gradient_loss | -0.018      |
# |    value_loss           | 57          |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1629        |
# |    iterations           | 3           |
# |    time_elapsed         | 3           |
# |    total_timesteps      | 6144        |
# | train/                  |             |
# |    approx_kl            | 0.010410186 |
# |    clip_fraction        | 0.0764      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.662      |
# |    explained_variance   | 0.0835      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 8.97        |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.0177     |
# |    value_loss           | 32          |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1577        |
# |    iterations           | 4           |
# |    time_elapsed         | 5           |
# |    total_timesteps      | 8192        |
# | train/                  |             |
# |    approx_kl            | 0.008725383 |
# |    clip_fraction        | 0.0788      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.636      |
# |    explained_variance   | 0.202       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 16.9        |
# |    n_updates            | 30          |
# |    policy_gradient_loss | -0.0175     |
# |    value_loss           | 49.6        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1548        |
# |    iterations           | 5           |
# |    time_elapsed         | 6           |
# |    total_timesteps      | 10240       |
# | train/                  |             |
# |    approx_kl            | 0.006655913 |
# |    clip_fraction        | 0.0651      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.615      |
# |    explained_variance   | 0.346       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 21.3        |
# |    n_updates            | 40          |
# |    policy_gradient_loss | -0.0158     |
# |    value_loss           | 53.6        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1516        |
# |    iterations           | 6           |
# |    time_elapsed         | 8           |
# |    total_timesteps      | 12288       |
# | train/                  |             |
# |    approx_kl            | 0.008912435 |
# |    clip_fraction        | 0.106       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.595      |
# |    explained_variance   | 0.598       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 17.5        |
# |    n_updates            | 50          |
# |    policy_gradient_loss | -0.0198     |
# |    value_loss           | 47.9        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1502        |
# |    iterations           | 7           |
# |    time_elapsed         | 9           |
# |    total_timesteps      | 14336       |
# | train/                  |             |
# |    approx_kl            | 0.007477404 |
# |    clip_fraction        | 0.0883      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.586      |
# |    explained_variance   | 0.513       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 26.4        |
# |    n_updates            | 60          |
# |    policy_gradient_loss | -0.0134     |
# |    value_loss           | 63.1        |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1492         |
# |    iterations           | 8            |
# |    time_elapsed         | 10           |
# |    total_timesteps      | 16384        |
# | train/                  |              |
# |    approx_kl            | 0.0046384986 |
# |    clip_fraction        | 0.0496       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.581       |
# |    explained_variance   | 0.505        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 20.1         |
# |    n_updates            | 70           |
# |    policy_gradient_loss | -0.00837     |
# |    value_loss           | 64.6         |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1490        |
# |    iterations           | 9           |
# |    time_elapsed         | 12          |
# |    total_timesteps      | 18432       |
# | train/                  |             |
# |    approx_kl            | 0.007296546 |
# |    clip_fraction        | 0.0556      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.565      |
# |    explained_variance   | 0.632       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 9.96        |
# |    n_updates            | 80          |
# |    policy_gradient_loss | -0.00574    |
# |    value_loss           | 63.5        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1491        |
# |    iterations           | 10          |
# |    time_elapsed         | 13          |
# |    total_timesteps      | 20480       |
# | train/                  |             |
# |    approx_kl            | 0.002763883 |
# |    clip_fraction        | 0.019       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.567      |
# |    explained_variance   | 0.473       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 77.8        |
# |    n_updates            | 90          |
# |    policy_gradient_loss | -0.00193    |
# |    value_loss           | 69.7        |
# -----------------------------------------

# %%
model =PPO.load(PPO_path, env=env)
# evaluate_policy(model, env, n_eval_episodes=10, render = True)


environment_name= "CartPole-v0"
env = gym.make(environment_name)

episodes = 5

for episode in range(1,episodes+1):
    obs = env.reset();
    done=False;
    score =0;
    
    while not done:
        i+=1
        env.render();
        action = model.predict(obs)
        obs, reward, done, info =env.step(action)
        score+=reward;
        
env.close()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-f11f04b3a797> in <module>
# ----> 1 model =PPO.load(PPO_path, env=env)
#       2 # evaluate_policy(model, env, n_eval_episodes=10, render = True)
#       3
#       4
#       5 environment_name= "CartPole-v0"
#
# NameError: name 'PPO' is not defined

# %%
env.close()

# %%
log_path = os.path.join('training','logs')

training_log_path =os.path.join(log_path, 'PPO_2')
# !tensorboard --logdir={training_log_path}
